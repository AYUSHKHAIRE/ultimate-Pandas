# %%
import pandas as pd

# %% [markdown]
# # Pandas Function

# %%
csv_1=pd.read_csv('/kaggle/input/sbi-n-55-01-analysis/SBIN55.csv')
csv_1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\THE  PROGRAMING\the Python programing laungage\Libreries study\Pandas\08-csv-func.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/THE%20%20PROGRAMING/the%20Python%20programing%20laungage/Libreries%20study/Pandas/08-csv-func.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> csv_1=pd.read_csv('/kaggle/input/sbi-n-55-01-analysis/SBIN55.csv')
#       <a href='vscode-notebook-cell:/d%3A/THE%20%20PROGRAMING/the%20Python%20programing%20laungage/Libreries%20study/Pandas/08-csv-func.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> csv_1
#
# ...

# %%
csv_1.index # stop = n+1

# %%
csv_1.columns # column

# %%
csv_1.describe()

# %%
csv_1.head(10)

# %%
csv_1.tail(10)

# %%
csv_1[:11]

# %%
csv_1[11:21]

# %%
csv_1[355:]

# %%
print(type(csv_1))

# %%
csv_1.index.array

# %%
csv_1.to_numpy()

# %%
import numpy as np

# %%
v=np.asarray(csv_1)
v

# %%
csv_1.sort_index(axis=0)

# %%
csv_1.sort_index(axis=0,ascending=False)

# %%
csv_1["Open"][0]=1000
csv_1
## not recommanded

# %%
csv_1.loc[0,"Open"]=10000
csv_1

# %%
csv_1.loc[(2,3),["High","Low"]]

# %%
csv_1.loc[:,["High","Low"]]

# %%
csv_1.loc[[2,3],:]

# %%
csv_1.iloc[0,1]

# %%
csv_1.drop("Open",axis=1)

# %%
csv_1.drop(0,axis=0)
