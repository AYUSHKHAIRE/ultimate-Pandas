# %%
import pandas as pd

# %% [markdown]
# # Read CSV files

# %%
csv_1=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv')
print(type(csv_1))
csv_1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\THE  PROGRAMING\the Python programing laungage\Libreries study\Pandas\07-read-csv.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/THE%20%20PROGRAMING/the%20Python%20programing%20laungage/Libreries%20study/Pandas/07-read-csv.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> csv_1=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv')
#       <a href='vscode-notebook-cell:/d%3A/THE%20%20PROGRAMING/the%20Python%20programing%20laungage/Libreries%20study/Pandas/07-read-csv.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> print(type(csv_1))
#       <a href='vscode-notebook-cell:/d%3A/THE%20%20PROGRAMING/the%20Python%20programing%20laungage/Libreries%20study/Pandas/07-read-csv.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> csv_1
#
# ...

# %%
csv_2=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',nrows=1)
print(type(csv_2))
csv_2

# %%
csv_3=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',usecols=['Open','High','Low','Close'])
csv_3

# %%
csv_4=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',usecols=[2,3,4,5])
csv_4

# %%
csv_5=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',skiprows=[0])
csv_5

# %%
csv_6=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',index_col="Open")
csv_6

# %%
csv_7=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',header=2)
csv_7

# %%
csv_8=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',names=['col'])
csv_8

# %%
csv_8=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',names=['col1','col2','col3','col4','col5','col6'])
csv_8

# %%
csv_9=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',header=None)
csv_9

# %%
csv_10=pd.read_csv('/kaggle/input/sbi-and-sample-data-stock-analysis/SBIN55.csv',dtype={"Vol":"float"})
csv_10
