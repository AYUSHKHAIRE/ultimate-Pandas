# %%
import pandas as pd

# %% [markdown]
# # DataFrame To CSV

# %% [markdown]
# csv : format to plane text
#
# excel : format to binary

# %%
dis = {"A":[1,2,3,4],"B":[5,6,7,8],"c":[7,8,9,0]}
d=pd.DataFrame(dis)
print(d)
d.to_csv("Text.csv")
# Text file has been created , with index number
# Out:
#    A  B  c
# 0  1  5  7
# 1  2  6  8
# 2  3  7  9
# 3  4  8  0

# %%
d.to_csv("Text1.csv",index=False) # without index

# %%
d.to_csv("Text2.csv",index=False,header=[1,2,3]) # change column name
